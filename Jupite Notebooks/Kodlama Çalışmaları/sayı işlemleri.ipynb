# %% [markdown]
# a+b+c+d=20 ve a.d=24 şartını sağlayan kaç adet 4 basamaklı sayı olduğunu bulan program.

# %%
toplam = 0
carpim = 1
for sayi in range (1000,10000):
    rakamlar = list(str(sayi))
    for i in rakamlar:
        toplam += int(i)
        carpim = i[0] * i[3]
        if toplam = 20 and carpim = 24
            print(sayi)
# Out:
#   File "<ipython-input-1-d22c12c1c125>", line 8
#     if toplam = 20 and carpim = 24
#               ^
# SyntaxError: invalid syntax

# %%
toplam = 0
carpim = 1
for sayi in range (1000,10000):
    rakamlar = list(str(sayi))
    for i in rakamlar:
        toplam += int(i)
        carpim = i[0] * i[3]
        if toplam == 20 and carpim == 24:
            print(sayi)
# Out:
#   File "<ipython-input-2-4372acbe7be2>", line 8
#     if toplam == 20 and carpim == 24
#                                     ^
# SyntaxError: invalid syntax

# %%
toplam = 0
carpim = 1
for sayi in range (1000,10000):
    rakamlar = list(str(sayi))
    for i in rakamlar:
        toplam += int(i)
        carpim = int(i[0]) * int(i[3])
        if toplam == 20 and carpim == 24:
            print(sayi)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-6484f1011f86> in <module>()
#       5     for i in rakamlar:
#       6         toplam += int(i)
# ----> 7         carpim = i[0] * i[3]
#       8         if toplam == 20 and carpim == 24:
#       9             print(sayi)
#
# IndexError: string index out of range

# %%
toplam = 0
carpim = 1
for sayi in range (1000,10000):
    rakamlar = list(str(sayi))
    for i in rakamlar:
        toplam += int(i)
        carpim = int(i[0]) * int(i[3])
        if toplam == 20 and carpim == 24:
            print(sayi)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-dde0002d4205> in <module>()
#       5     for i in rakamlar:
#       6         toplam += int(i)
# ----> 7         carpim = int(i[0]) * int(i[3])
#       8         if toplam == 20 and carpim == 24:
#       9             print(sayi)
#
# IndexError: string index out of range

# %%
toplam = 0
carpim = 1
for sayi in range (1000,10000):
    rakamlar = list(str(sayi))
    print("1",rakamlar)
    for i in rakamlar:
        print("2",i)
        toplam += int(i)
        print(toplam)
        carpim = int(i[0]) * int(i[3])
        print(carpim)
        if toplam == 20 and carpim == 24:
            print(sayi)
# Out:
# ['1', '0', '0', '0']
# 1
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-549e97ee52ae> in <module>()
#       8         toplam += int(i)
#       9         print(toplam)
# ---> 10         carpim = int(i[0]) * int(i[3])
#      11         print(carpim)
#      12         if toplam == 20 and carpim == 24:
#
# IndexError: string index out of range

# %%
toplam = 0
carpim = 1
for sayi in range (1000,10000):
    rakamlar = list(str(sayi))
    print(rakamlar)
    for i in rakamlar:
        print(i,i[0],i[3])
        toplam += int(i)
        print(toplam)
        carpim = int(i[0]) * int(i[3])
        print(carpim)
        if toplam == 20 and carpim == 24:
            print(sayi)
# Out:
# ['1', '0', '0', '0']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-365fdaf8491f> in <module>()
#       5     print(rakamlar)
#       6     for i in rakamlar:
# ----> 7         print(i,i[0],i[3])
#       8         toplam += int(i)
#       9         print(toplam)
#
# IndexError: string index out of range

# %%
toplam = 0
carpim = 1
for sayi in range (1000,10000):
    rakamlar = list(str(sayi))
    print("1.",rakamlar)
    for i in rakamlar:
        print("2.",i)
        toplam += int(i)
        print("3.",toplam)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    print("4.",carpim)
    if toplam == 20 and carpim == 24:
        print(sayi)
# Out:
# 1 ['1', '0', '0', '0']
# 2 1
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-78a777b4ef58> in <module>()
#       8         toplam += int(i)
#       9         print(toplam)
# ---> 10         carpim = int(i[0]) * int(i[3])
#      11         print(carpim)
#      12         if toplam == 20 and carpim == 24:
#
# IndexError: string index out of range

# %%
toplam = 0
carpim = 1
for sayi in range (1000,1501):
    rakamlar = list(str(sayi))
    #print("1.",rakamlar)
    for i in rakamlar:
        #print("2.",i)
        toplam += int(i)
        #print("3.",toplam)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    #print("4.",carpim)
    if toplam == 20 and carpim == 24:
        print(sayi)
# Out:
# 1. ['1', '0', '0', '0']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 4. 0
# 1. ['1', '0', '0', '1']
# 2. 1
# 3. 2
# 2. 0
# 3. 2
# 2. 0
# 3. 2
# 2. 1
# 3. 3
# 4. 1
# 1. ['1', '0', '0', '2']
# 2. 1
# 3. 4
# 2. 0
# 3. 4
# 2. 0
# 3. 4
# 2. 2
# 3. 6
# 4. 2
# 1. ['1', '0', '0', '3']
# 2. 1
# 3. 7
# 2. 0
# 3. 7
# 2. 0
# 3. 7
# 2. 3
# 3. 10
# 4. 3
# 1. ['1', '0', '0', '4']
# 2. 1
# 3. 11
# 2. 0
# 3. 11
# 2. 0
# 3. 11
# 2. 4
# 3. 15
# 4. 4
# 1. ['1', '0', '0', '5']
# 2. 1
# 3. 16
# 2. 0
# 3. 16
# 2. 0
# 3. 16
# 2. 5
# 3. 21
# 4. 5
# 1. ['1', '0', '0', '6']
# 2. 1
# 3. 22
# 2. 0
# 3. 22
# 2. 0
# 3. 22
# 2. 6
# 3. 28
# 4. 6
# 1. ['1', '0', '0', '7']
# 2. 1
# 3. 29
# 2. 0
# 3. 29
# 2. 0
# 3. 29
# 2. 7
# 3. 36
# 4. 7
# 1. ['1', '0', '0', '8']
# 2. 1
# 3. 37
# 2. 0
# 3. 37
# 2. 0
# 3. 37
# 2. 8
# 3. 45
# 4. 8
# 1. ['1', '0', '0', '9']
# 2. 1
# 3. 46
# 2. 0
# 3. 46
# 2. 0
# 3. 46
# 2. 9
# 3. 55
# 4. 9
# 1. ['1', '0', '1', '0']
# 2. 1
# 3. 56
# 2. 0
# 3. 56
# 2. 1
# 3. 57
# 2. 0
# ...

# %%
toplam = 0
carpim = 1
for sayi in range (1000,1101):
    rakamlar = list(str(sayi))
    #print("1.",rakamlar)
    for i in rakamlar:
        #print("2.",i)
        toplam += int(i)
        #print("3.",toplam)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    #print("4.",carpim)
    if toplam == 20 and carpim == 24:
        print(sayi)

# %%
toplam = 0
carpim = 1
for sayi in range (1000,1011):
    rakamlar = list(str(sayi))
    print("1.",rakamlar)
    for i in rakamlar:
        print("2.",i)
        toplam += int(i)
        print("3.",toplam)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    print("4.",carpim)
    if toplam == 20 and carpim == 24:
        print("5.",sayi)
# Out:
# 3. 1
# 3. 1
# 3. 1
# 3. 1
# 4. 0
# 3. 2
# 3. 2
# 3. 2
# 3. 3
# 4. 1
# 3. 4
# 3. 4
# 3. 4
# 3. 6
# 4. 2
# 3. 7
# 3. 7
# 3. 7
# 3. 10
# 4. 3
# 3. 11
# 3. 11
# 3. 11
# 3. 15
# 4. 4
# 3. 16
# 3. 16
# 3. 16
# 3. 21
# 4. 5
# 3. 22
# 3. 22
# 3. 22
# 3. 28
# 4. 6
# 3. 29
# 3. 29
# 3. 29
# 3. 36
# 4. 7
# 3. 37
# 3. 37
# 3. 37
# 3. 45
# 4. 8
# 3. 46
# 3. 46
# 3. 46
# 3. 55
# 4. 9
# 3. 56
# 3. 56
# 3. 57
# 3. 57
# 4. 0
# 3. 58
# 3. 58
# 3. 59
# 3. 60
# 4. 1
# 3. 61
# 3. 61
# 3. 62
# 3. 64
# 4. 2
# 3. 65
# 3. 65
# 3. 66
# 3. 69
# 4. 3
# 3. 70
# 3. 70
# 3. 71
# 3. 75
# 4. 4
# 3. 76
# 3. 76
# 3. 77
# 3. 82
# 4. 5
# 3. 83
# 3. 83
# 3. 84
# 3. 90
# 4. 6
# 3. 91
# 3. 91
# 3. 92
# 3. 99
# 4. 7
# 3. 100
# 3. 100
# 3. 101
# 3. 109
# 4. 8
# 3. 110
# 3. 110
# 3. 111
# 3. 120
# 4. 9
# 3. 121
# 3. 121
# 3. 123
# 3. 123
# 4. 0
# 3. 124
# 3. 124
# 3. 126
# 3. 127
# 4. 1
# 3. 128
# 3. 128
# 3. 130
# 3. 132
# 4. 2
# 3. 133
# 3. 133
# 3. 135
# 3. 138
# 4. 3
# 3. 139
# 3. 139
# 3. 141
# 3. 145
# 4. 4
# 3. 146
# ...

# %%
toplam = 0
carpim = 1
for sayi in range (1000,1011):
    toplam = 0
    carpim = 1
    rakamlar = list(str(sayi))
    print("1.",rakamlar)
    for i in rakamlar:
        print("2.",i)
        toplam += int(i)
        print("3.",toplam)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    print("4.",carpim)
    if toplam == 20 and carpim == 24:
        print("5.",sayi)
# Out:
# 1. ['1', '0', '0', '0']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 4. 0
# 1. ['1', '0', '0', '1']
# 2. 1
# 3. 2
# 2. 0
# 3. 2
# 2. 0
# 3. 2
# 2. 1
# 3. 3
# 4. 1
# 1. ['1', '0', '0', '2']
# 2. 1
# 3. 4
# 2. 0
# 3. 4
# 2. 0
# 3. 4
# 2. 2
# 3. 6
# 4. 2
# 1. ['1', '0', '0', '3']
# 2. 1
# 3. 7
# 2. 0
# 3. 7
# 2. 0
# 3. 7
# 2. 3
# 3. 10
# 4. 3
# 1. ['1', '0', '0', '4']
# 2. 1
# 3. 11
# 2. 0
# 3. 11
# 2. 0
# 3. 11
# 2. 4
# 3. 15
# 4. 4
# 1. ['1', '0', '0', '5']
# 2. 1
# 3. 16
# 2. 0
# 3. 16
# 2. 0
# 3. 16
# 2. 5
# 3. 21
# 4. 5
# 1. ['1', '0', '0', '6']
# 2. 1
# 3. 22
# 2. 0
# 3. 22
# 2. 0
# 3. 22
# 2. 6
# 3. 28
# 4. 6
# 1. ['1', '0', '0', '7']
# 2. 1
# 3. 29
# 2. 0
# 3. 29
# 2. 0
# 3. 29
# 2. 7
# 3. 36
# 4. 7
# 1. ['1', '0', '0', '8']
# 2. 1
# 3. 37
# 2. 0
# 3. 37
# 2. 0
# 3. 37
# 2. 8
# 3. 45
# 4. 8
# 1. ['1', '0', '0', '9']
# 2. 1
# 3. 46
# 2. 0
# 3. 46
# 2. 0
# 3. 46
# 2. 9
# 3. 55
# 4. 9
# 1. ['1', '0', '1', '0']
# 2. 1
# 3. 56
# 2. 0
# 3. 56
# 2. 1
# 3. 57
# 2. 0
# ...

# %%
toplam = 0
carpim = 1
for sayi in range (1000,1011):
    toplam = 0
    carpim = 1
    rakamlar = list(str(sayi))
    print("1.",rakamlar)
    for i in rakamlar:
        print("2.",i)
        toplam += int(i)
        print("3.",toplam)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    print("4.",carpim)
    if toplam == 20 and carpim == 24:
        print("5.",sayi)
# Out:
# 1. ['1', '0', '0', '0']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 4. 0
# 1. ['1', '0', '0', '1']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 1
# 3. 2
# 4. 1
# 1. ['1', '0', '0', '2']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 2
# 3. 3
# 4. 2
# 1. ['1', '0', '0', '3']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 3
# 3. 4
# 4. 3
# 1. ['1', '0', '0', '4']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 4
# 3. 5
# 4. 4
# 1. ['1', '0', '0', '5']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 5
# 3. 6
# 4. 5
# 1. ['1', '0', '0', '6']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 6
# 3. 7
# 4. 6
# 1. ['1', '0', '0', '7']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 7
# 3. 8
# 4. 7
# 1. ['1', '0', '0', '8']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 8
# 3. 9
# 4. 8
# 1. ['1', '0', '0', '9']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 0
# 3. 1
# 2. 9
# 3. 10
# 4. 9
# 1. ['1', '0', '1', '0']
# 2. 1
# 3. 1
# 2. 0
# 3. 1
# 2. 1
# 3. 2
# 2. 0
# 3. 2
# 4. 0

# %%
toplam = 0
carpim = 1
for sayi in range (1000,10001):
    toplam = 0
    carpim = 1
    rakamlar = list(str(sayi))
    #print("1.",rakamlar)
    for i in rakamlar:
        #print("2.",i)
        toplam += int(i)
        #print("3.",toplam)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    #print("4.",carpim)
    if toplam == 20 and carpim == 24:
        print("5.",sayi)

# %%
liste = list()
for sayi in range (1000,10001):
    toplam = 0
    carpim = 1
    rakamlar = list(str(sayi))
    #print("1.",rakamlar)
    for i in rakamlar:
        #print("2.",i)
        toplam += int(i)
        #print("3.",toplam)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    #print("4.",carpim)
    if toplam == 20 and carpim == 24:
        #print("5.",sayi)
        liste.append(sayi)

print(liste)
# Out:
# [3098, 3188, 3278, 3368, 3458, 3548, 3638, 3728, 3818, 3908, 4196, 4286, 4376, 4466, 4556, 4646, 4736, 4826, 4916, 6194, 6284, 6374, 6464, 6554, 6644, 6734, 6824, 6914, 8093, 8183, 8273, 8363, 8453, 8543, 8633, 8723, 8813, 8903]

# %%
def hesapla(x):
    toplam = 0
    carpım = 1
    rakamlar = list(str(x))
    for i in rakamlar:
        toplam += int(i)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    if toplam == 20 and carpim == 24:
        return x

print(list(map(hesapla,range(1000,10000))))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c7d661e3b407> in <module>()
#       9         return x
#      10
# ---> 11 print(list(map(hesapla,range(1000,10000))))
#      12
#
# <ipython-input-16-c7d661e3b407> in hesapla(x)
#       4     rakamlar = list(str(x))
#       5     for i in rakamlar:
# ----> 6         toplam += i
#       7     carpim = int(rakamlar[0]) * int(rakamlar[3])
#       8     if toplam == 20 and carpim == 24:
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
def hesapla(x):
    toplam = 0
    carpım = 1
    rakamlar = list(str(x))
    for i in rakamlar:
        toplam += int(i)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    if toplam == 20 and carpim == 24:
        return x

print(list(map(hesapla,(range(1000,10000))))
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, N
# ...

# %%
def hesapla(x):
    toplam = 0
    carpım = 1
    rakamlar = list(str(x))
    for i in rakamlar:
        toplam += int(i)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    if toplam == 20 and carpim == 24:
        return True

print(list(filter(hesapla,[1000,1234,1222,2345,3456,4567,7890,3908])))
# Out:
# [3908]

# %%
def hesapla(x):
    toplam = 0
    carpım = 1
    rakamlar = list(str(x))
    for i in rakamlar:
        toplam += int(i)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    if toplam == 20 and carpim == 24:
        return True

print(list(filter(hesapla,range(1000,10000))))
# Out:
# [3098, 3188, 3278, 3368, 3458, 3548, 3638, 3728, 3818, 3908, 4196, 4286, 4376, 4466, 4556, 4646, 4736, 4826, 4916, 6194, 6284, 6374, 6464, 6554, 6644, 6734, 6824, 6914, 8093, 8183, 8273, 8363, 8453, 8543, 8633, 8723, 8813, 8903]

# %%
def hesapla(x):
    toplam = 0
    carpım = 1
    rakamlar = list(str(x))
    for i in rakamlar:
        toplam += int(i)
    carpim = int(rakamlar[0]) * int(rakamlar[3])
    if toplam == 20 and carpim == 24:
        return x
    else:
        pass

print(list(map(hesapla,[1000,1234,1222,2345,3456,4567,7890,3908])))
print(hesapla(1001))
# Out:
# [None, None, None, None, None, None, None, 3908]
# None
